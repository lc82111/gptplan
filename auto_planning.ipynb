# %%
from agent_team import AgentTeam
from database import CervicalCancerDB
from rag import RAG

# %%
# setup DB
db = CervicalCancerDB()
print("all patient names in DB:")
print(db.get_all_patient_names())

# setup RAG based on DB
rag = RAG(db)

# setup autoplanning team
team = AgentTeam(db, rag)

# setup planning task
init_msg = team.get_initmsg(patient_name="ZXY", top_n=2)

# run auto planning
team.run_auto_planning(init_msg)
# Out:
# all patient names in DB:
# ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'ZXY']
# Reference Plans based on OARs' Overlap Percentages Similarity:
#     Patient-Name    Rectum   Bladder  Bowel_bag  Femoral_head_L  \
# 0  Query Patient  0.126497  0.286670   0.041891             0.0
# 1              I  0.258065  0.193435   0.032911             0.0
# 2              H  0.361328  0.403633   0.025002             0.0
#
#    Femoral_head_R  Similarity Score
# 0             0.0               NaN
# 1             0.0          0.896024
# 2             0.0          0.834110
# task_initializer (to chat_manager):
#
#
# # Planning Task: Optimize radiotherapy plan for cervical cancer patient ZXY.
#
# ## Patient ZXY Profile:
#
# ### Anatomy
#
# - Structures and Volumes:
#
# | ROIs                       | Volume (cm³)              |
# |----------------------------|---------------------------|
# | PTV                        | 1078.50  |
# | Bladder                    | 512.74  |
# | Rectum                     | 119.44  |
# | Bowel Bag                  | 2865.26  |
# | Femoral Head (L)           | 40.56  |
# | Femoral Head (R)           | 40.69  |
# | Ring around PTV (R1)       | 495.73  |
# | Ring around PTV (R2)       | 875.08  |
# | Ring around PTV (R3)       | 1058.64  |
# | Normal Tissue (NT)         | 29059.10 |
#
# - Overlapping Volumes with PTV:
#
# | Structure                  |  Volume (cm³)             | Overlap Percentage |
# |----------------------------|---------------------------| -------------------|
# | Rectum                     | 15.11 | 0.13 |
# | Bladder                    | 146.99 | 0.29 |
# | Bowel Bag                  | 120.03 | 0.04 |
# | Femoral Heads (L & R)      | 0.00, 0.00 | 0.00, 0.00 |
#
#
# ### Dose Objective & Constraint
#
# | OARs            | Criterion              | Specification|
# |---------------------|--------------------|-------------------------------------------|
# | Prescribed Dose (PD) | NA                | 5040 cGy delivered in 28 fractions|
# | PTV             | D95 ≥ 100% PD          | At least 95% volume receive 100% of PD|
# | PTV             | Max Dose ≤ 110% PD     | Maximum dose not exceed 110% of PD|
# | PTV             | Uniformity             | as uniform as possible|
# | Rectum & Bladder| V50 ≤ 50%              | less than 50% volume receive more than 5000 cGy|
# | Bowel Bag       | V45 ≤ 195 cm³          | less than 195 cm³ volume receive more than 4500 cGy|
# | Femoral Head    | V50 ≤ 5%               | less than 5% volume receive more than 5000 cGy|
#
#
# ### Delivery Technique
#
# | Item | Value |
# |-----------------|-----------------|
# | Position        | Prone           |
# | Technique       | VMAT with Dual arcs 181°->179° (CW), 179°->181° (CCW) |
#
#
# # Reference Plans:
# Use provided parameters for Reference Patients as guidance, adapting for Patient ZXY's anatomy and objectives.
# All reference plans are based on the same delivery technique and dose objectives as Patient ZXY.
#
# ## Patient I:
#
# ### Anatomy
#
# - Structures and Volumes:
#
# | ROIs                       | Volume (cm³)              |
# |----------------------------|---------------------------|
# | PTV                        | 1030.37  |
# | Bladder                    | 375.26  |
# | Rectum                     | 44.36  |
# | Bowel Bag                  | 2672.33  |
# | Femoral Head (L)           | 45.81  |
# | Femoral Head (R)           | 46.33  |
# | Ring around PTV (R1)       | 471.14  |
# | Ring around PTV (R2)       | 888.08  |
# | Ring around PTV (R3)       | 1035.01  |
# | Normal Tissue (NT)         | 28054.70 |
#
# - Overlapping Volumes with PTV:
#
# | Structure                  |  Volume (cm³)             | Overlap Percentage |
# |----------------------------|---------------------------| -------------------|
# | Rectum                     | 11.45 | 0.26 |
# | Bladder                    | 72.59 | 0.19 |
# | Bowel Bag                  | 87.95 | 0.03 |
# | Femoral Heads (L & R)      | 0.00, 0.00 | 0.00, 0.00 |
#
#
# ### OptPara
#
# | ROI Name | Objective Type | Target cGy | % Volume | Weight |
# |----------|----------------|------------|----------|--------|
# | PTV | Max Dose | 5230.0 | NA | 60 |
# | PTV | Min DVH | 5040.0 | 95.0 | 90 |
# | PTV | Min Dose | 4990.0 | NA | 90 |
# | PTV | Uniform Dose | 5140.0 | NA | 1 |
# | bladder | Max DVH | 4000.0 | 33.0 | 30 |
# | bladder | Max DVH | 5000.0 | 15.0 | 30 |
# | bladder | Max EUD | 2900.0 | NA | 1 |
# | bowel_bag | Max DVH | 4000.0 | 5.0 | 30 |
# | bowel_bag | Max DVH | 4500.0 | 4.0 | 40 |
# | bowel_bag | Max DVH | 5000.0 | 3.0 | 30 |
# | bowel_bag | Max Dose | 5230.0 | NA | 40 |
# | bowel_bag | Max EUD | 1050.0 | NA | 1 |
# | femoral_head_l | Max DVH | 3000.0 | 5.0 | 30 |
# | femoral_head_l | Max DVH | 5000.0 | 1.0 | 30 |
# | femoral_head_l | Max EUD | 1100.0 | NA | 1 |
# | femoral_head_r | Max DVH | 3000.0 | 3.0 | 30 |
# | femoral_head_r | Max DVH | 5000.0 | 1.0 | 30 |
# | femoral_head_r | Max EUD | 970.0 | NA | 1 |
# | nt | Max Dose | 3100.0 | NA | 30 |
# | r1 | Max Dose | 4900.0 | NA | 30 |
# | r2 | Max Dose | 4200.0 | NA | 30 |
# | r3 | Max Dose | 3200.0 | NA | 30 |
# | rectum | Max DVH | 4000.0 | 37.0 | 30 |
# | rectum | Max DVH | 5000.0 | 14.0 | 30 |
# | rectum | Max EUD | 3200.0 | NA | 1 |
#
#
# ## Patient H:
#
# ### Anatomy
#
# - Structures and Volumes:
#
# | ROIs                       | Volume (cm³)              |
# |----------------------------|---------------------------|
# | PTV                        | 1010.42  |
# | Bladder                    | 173.91  |
# | Rectum                     | 33.72  |
# | Bowel Bag                  | 2024.78  |
# | Femoral Head (L)           | 40.16  |
# | Femoral Head (R)           | 42.49  |
# | Ring around PTV (R1)       | 516.52  |
# | Ring around PTV (R2)       | 908.72  |
# | Ring around PTV (R3)       | 1097.52  |
# | Normal Tissue (NT)         | 27052.50 |
#
# - Overlapping Volumes with PTV:
#
# | Structure                  |  Volume (cm³)             | Overlap Percentage |
# |----------------------------|---------------------------| -------------------|
# | Rectum                     | 12.19 | 0.36 |
# | Bladder                    | 70.20 | 0.40 |
# | Bowel Bag                  | 50.62 | 0.03 |
# | Femoral Heads (L & R)      | 0.00, 0.00 | 0.00, 0.00 |
#
#
# ### OptPara
#
# | ROI Name | Objective Type | Target cGy | % Volume | Weight |
# |----------|----------------|------------|----------|--------|
# | PTV | Max Dose | 5270.0 | NA | 60 |
# | PTV | Min DVH | 5040.0 | 95.0 | 95 |
# | PTV | Min Dose | 4990.0 | NA | 100 |
# | PTV | Uniform Dose | 5160.0 | NA | 1 |
# | bladder | Max DVH | 3000.0 | 78.0 | 10 |
# | bladder | Max DVH | 4000.0 | 56.0 | 20 |
# | bladder | Max DVH | 5000.0 | 32.0 | 30 |
# | bladder | Max EUD | 3900.0 | NA | 1 |
# | bowel_bag | Max DVH | 4000.0 | 4.0 | 30 |
# | bowel_bag | Max DVH | 4500.0 | 3.0 | 40 |
# | bowel_bag | Max DVH | 5000.0 | 2.0 | 30 |
# | bowel_bag | Max Dose | 5180.0 | NA | 30 |
# | bowel_bag | Max EUD | 1050.0 | NA | 1 |
# | femoral_head_l | Max DVH | 3000.0 | 2.0 | 30 |
# | femoral_head_l | Max DVH | 5000.0 | 1.0 | 30 |
# | femoral_head_l | Max EUD | 1100.0 | NA | 1 |
# | femoral_head_r | Max DVH | 3000.0 | 2.0 | 30 |
# | femoral_head_r | Max DVH | 5000.0 | 1.0 | 30 |
# | femoral_head_r | Max EUD | 1150.0 | NA | 1 |
# | nt | Max Dose | 3100.0 | NA | 30 |
# | r1 | Max Dose | 4900.0 | NA | 30 |
# | r2 | Max Dose | 4200.0 | NA | 30 |
# | r3 | Max Dose | 3300.0 | NA | 30 |
# | rectum | Max DVH | 4000.0 | 43.0 | 20 |
# | rectum | Max DVH | 5000.0 | 21.0 | 30 |
# | rectum | Max EUD | 3200.0 | NA | 1 |
#
#
#
#
# --------------------------------------------------------------------------------
# dosimetrist (to chat_manager):
#
# ### OptPara Proposal:
# {
# | ROI Name           | Objective Type | Target cGy | % Volume | Weight |
# |--------------------|----------------|------------|----------|--------|
# | PTV                | Max Dose       | 5230       | NA       | 60     |
# | PTV                | Min DVH        | 5040       | 95       | 90     |
# | PTV                | Min Dose       | 4990       | NA       | 90     |
# | PTV                | Uniform Dose   | 5140       | NA       | 1      |
# | Rectum             | Max DVH        | 4000       | 37       | 30     |
# | Rectum             | Max DVH        | 5000       | 14       | 30     |
# | Rectum             | Max EUD        | 3200       | NA       | 1      |
# | Bladder            | Max DVH        | 4000       | 33       | 30     |
# | Bladder            | Max DVH        | 5000       | 15       | 30     |
# | Bladder            | Max EUD        | 2900       | NA       | 1      |
# | Bowel Bag          | Max DVH        | 4000       | 5        | 30     |
# | Bowel Bag          | Max DVH        | 4500       | 4        | 40     |
# | Bowel Bag          | Max DVH        | 5000       | 3        | 30     |
# | Femoral Head (L)   | Max DVH        | 3000       | 5        | 30     |
# | Femoral Head (L)   | Max DVH        | 5000       | 1        | 30     |
# | Femoral Head (L)   | Max EUD        | 1100       | NA       | 1      |
# | Femoral Head (R)   | Max DVH        | 3000       | 3        | 30     |
# | Femoral Head (R)   | Max DVH        | 5000       | 1        | 30     |
# | Femoral Head (R)   | Max EUD        | 970        | NA       | 1      |
# | NT                 | Max Dose       | 3100       | NA       | 30     |
# | R1                 | Max Dose       | 4900       | NA       | 30     |
# | R2                 | Max Dose       | 4200       | NA       | 30     |
# | R3                 | Max Dose       | 3200       | NA       | 30     |
# }
#
# ### Rationale:
# 1. **PTV**: Ensure that the PTV receives adequate dose coverage with minimal dose heterogeneity while avoiding excessive doses.
# 2. **Rectum and Bladder**: Maintain acceptable dose constraints to minimize potential side effects, following clinical guidelines to keep doses within tolerance levels.
# 3. **Bowel Bag**: Control doses to the bowel bag to prevent toxicity, particularly by limiting high-dose exposure volumes.
# 4. **Femoral Heads**: Limit dose to femoral heads to reduce the risk of avascular necrosis.
# 5. **Normal Tissue (NT)**: Protect surrounding normal tissue from excessive radiation, preserving overall healthy tissue integrity.
# 6. **Rings (R1, R2, R3)**: Use ring structures to control dose fall-off outside the PTV, ensuring a steep dose gradient and minimizing exposure to adjacent organs at risk.
#
# --------------------------------------------------------------------------------

# %% [markdown]
# The dosimetric outcomes of the optimized plan generated by Pinnacle TPS:  PTV: D95 is 5063.19 cGy; Max Dose is 5758.2 cGy; Min Dose is 4201 cGy; Mean Dose is 5301.3cGy.  Bladder: Max Dose is 5648.7 cGy; Mean Dose is 3759.1 cGy; V50 is 29%; V40 is 48%; V30 is 68%; V20 is 85%; V10 is 99%.  Rectum: Max Dose is 5534.9 cGy; Mean Dose is 3989.3 cGy; V50 is 42%; V40 is 59%; V30 is 70%; V20 is 85%; V10 is 100%.  BowelBag: Max Dose is 5524.2 cGy; Mean Dose is 1346.5 cGy; V50 is 5%; V40 is 7%; V30 is 11%; V20 is 23%; V10 is 48%.  FemoralHead_L: Max Dose is 4585 cGy; Mean Dose is 1712.1 cGy; V50 is 0%; V40 is 2%; V30 is 8%; V20 is 29%; V10 is 83%.  FemoralHead_R: Max Dose is 4481.6 cGy; Mean Dose is 1751.7 cGy; V50 is 0%; V40 is 0.39%; V30 is 7%; V20 is 32%; V10 is 86%
